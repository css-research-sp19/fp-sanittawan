# %% [markdown]
# ### Code for joining datasets (BMR, FH, VDEM)
#
# ### Sanittawan Tan

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### check for country name discrepancies and standardize

# %%
fh = pd.read_csv('./cleaned_FH.csv')
bmr = pd.read_csv('./cleaned_BMR.csv')
vdem = pd.read_csv('./cleaned_VDEM.csv')

# %%
FH_set = set(fh['country'].unique())

# %%
len(FH_set)
# Out:
# 195

# %%
BMR_set = set(bmr['country'].unique())

# %%
len(BMR_set)
# Out:
# 196

# %%
VDEM_set = set(vdem['country'].unique())

# %%
len(VDEM_set)
# Out:
# 179

# %%
FH_BMR = FH_set - BMR_set
FH_BMR
# Out:
# {'antigua and barbuda',
#  'bosnia and herzegovina',
#  'central african republic',
#  'congo (brazzaville)',
#  'congo (kinshasa)',
#  'liechtenstein',
#  'micronesia',
#  'north korea',
#  'samoa',
#  'sao tome and principe',
#  'south korea',
#  'south sudan',
#  'st. kitts and nevis',
#  'st. vincent and the grenadines',
#  'the gambia',
#  'timor-leste',
#  'trinidad and tobago'}

# %%
fh['country'].replace({'congo (brazzaville)': 'rep. of congo',
                       'congo (kinshasa)': 'dem. rep. of congo'}, inplace=True)

# %%
BMR_FH = BMR_set - FH_set
BMR_FH
# Out:
# {'antigua',
#  'bosnia',
#  'central african rep.',
#  'congo, dem. rep.',
#  'congo, rep.',
#  'east timor',
#  'gambia',
#  'korea, north',
#  'korea, south',
#  'liechstenstein',
#  'micronesia, fed.',
#  'samoa (western)',
#  'sao tome & principe',
#  'st. kitts & nevis',
#  'st. vincent & gren.',
#  'sudan, north',
#  'sudan, south',
#  'trinidad & tobago'}

# %%
bmr_replace = {'antigua': 'antigua and barbuda',
 'bosnia': 'bosnia and herzegovina',
 'central african rep.': 'central african republic',
 'congo, dem. rep.': 'dem. rep. of congo',
 'congo, rep.': 'rep. of congo',
 'east timor': 'timor-leste',
 'gambia': 'the gambia',
 'korea, north': 'north korea',
 'korea, south': 'south korea',
 'liechstenstein': 'liechtenstein',
 'micronesia, fed.': 'micronesia',
 'samoa (western)': 'samoa',
 'sao tome & principe': 'sao tome and principe',
 'st. kitts & nevis': 'st. kitts and nevis',
 'st. vincent & gren.': 'st. vincent and the grenadines',
 'sudan, north': 'sudan',
 'sudan, south': 'south sudan',
 'trinidad & tobago': 'trinidad and tobago'}
bmr['country'].replace(bmr_replace, inplace=True)

# %%
FH_set = set(fh['country'].unique())
BMR_set = set(bmr['country'].unique())
print(FH_set - BMR_set)
print(BMR_set - FH_set)
# Out:
# set()
# set()

# %%
FH_VDEM = FH_set - VDEM_set
FH_VDEM
# Out:
# {'andorra',
#  'antigua and barbuda',
#  'bahamas',
#  'belize',
#  'brunei',
#  "cote d'ivoire",
#  'dem. rep. of congo',
#  'dominica',
#  'grenada',
#  'kiribati',
#  'liechtenstein',
#  'marshall islands',
#  'micronesia',
#  'monaco',
#  'myanmar',
#  'nauru',
#  'palau',
#  'rep. of congo',
#  'samoa',
#  'san marino',
#  'st. kitts and nevis',
#  'st. lucia',
#  'st. vincent and the grenadines',
#  'tonga',
#  'tuvalu'}

# %%
VDEM_FH = VDEM_set - FH_set
VDEM_FH
# Out:
# {'burma/myanmar',
#  'democratic republic of the congo',
#  'hong kong',
#  'ivory coast',
#  'palestine/gaza',
#  'palestine/west bank',
#  'republic of the congo',
#  'somaliland',
#  'zanzibar'}

# %%
vdem_replace = {'burma/myanmar': 'myanmar',
 'democratic republic of the congo': 'dem. rep. of congo',
 'republic of the congo': 'rep. of congo',
 'ivory coast': "cote d'ivoire"}
vdem['country'].replace(vdem_replace, inplace=True)

# %%
FH_set = set(fh['country'].unique())
VDEM_set = set(vdem['country'].unique())
print(FH_set - VDEM_set)
print(VDEM_set - FH_set)
# Out:
# {'grenada', 'nauru', 'kiribati', 'palau', 'dominica', 'monaco', 'liechtenstein', 'belize', 'brunei', 'tuvalu', 'st. vincent and the grenadines', 'samoa', 'bahamas', 'san marino', 'micronesia', 'andorra', 'tonga', 'st. kitts and nevis', 'marshall islands', 'st. lucia', 'antigua and barbuda'}
# {'zanzibar', 'somaliland', 'palestine/gaza', 'palestine/west bank', 'hong kong'}

# %%
len(FH_set)
# Out:
# 195

# %%
len(BMR_set)
# Out:
# 195

# %%
len(VDEM_set)
# Out:
# 179

# %%
fh.dtypes
# Out:
# country        object
# year            int64
# PR              int64
# CL              int64
# Status         object
# FH_category     int64
# FH_F            int64
# FH_NF           int64
# FH_PF           int64
# dtype: object

# %%
bmr.dtypes
# Out:
# country                      object
# year                          int64
# BMR_democracy               float64
# BMR_democracy_trans         float64
# BMR_democracy_breakdowns    float64
# BMR_democracy_duration      float64
# dtype: object

# %% [markdown]
# ### Join datasets

# %%
mid_data = fh.merge(bmr, on=['country', 'year'], how='left')

# %%
final_data = mid_data.merge(vdem, on=['country', 'year'], how='left')

# %%
final_data
# Out:
#           country  year  PR  CL Status  FH_category  FH_F  FH_NF  FH_PF  \
# 0     afghanistan  2008   5   6     NF            0     0      1      0
# 1     afghanistan  2009   6   6     NF            0     0      1      0
# 2     afghanistan  2010   6   6     NF            0     0      1      0
# 3     afghanistan  2011   6   6     NF            0     0      1      0
# 4     afghanistan  2012   6   6     NF            0     0      1      0
# 5     afghanistan  2013   6   6     NF            0     0      1      0
# 6     afghanistan  2014   6   6     NF            0     0      1      0
# 7     afghanistan  2015   6   6     NF            0     0      1      0
# 8     afghanistan  2016   6   6     NF            0     0      1      0
# 9     afghanistan  2017   5   6     NF            0     0      1      0
# 10        albania  2008   3   3     PF            1     0      0      1
# 11        albania  2009   3   3     PF            1     0      0      1
# 12        albania  2010   3   3     PF            1     0      0      1
# 13        albania  2011   3   3     PF            1     0      0      1
# 14        albania  2012   3   3     PF            1     0      0      1
# 15        albania  2013   3   3     PF            1     0      0      1
# 16        albania  2014   3   3     PF            1     0      0      1
# 17        albania  2015   3   3     PF            1     0      0      1
# 18        albania  2016   3   3     PF            1     0      0      1
# 19        albania  2017   3   3     PF            1     0      0      1
# 20        algeria  2008   6   5     NF            0     0      1      0
# 21        algeria  2009   6   5     NF            0     0      1      0
# 22        algeria  2010   6   5     NF            0     0      1      0
# 23        algeria  2011   6   5     NF            0     0      1      0
# 24        algeria  2012   6   5     NF            0     0      1      0
# 25        algeria  2013   6   5     NF            0     0      1      0
# 26        algeria  2014   6   5     NF            0     0      1      0
# 27        algeria  2015   6   5     NF            0     0      1      0
# 28        algeria  2016   6   5     NF            0     0      1      0
# 29        algeria  2017   6   5     NF            0     0      1      0
# ...           ...   ...  ..  ..    ...          ...   ...    ...    ...
# 1916        yemen  2008   5   5     PF            1     0      0      1
# 1917        yemen  2009   6   5     NF            0     0      1      0
# 1918        yemen  2010   6   5     NF            0     0      1      0
# 1919        yemen  2011   6   6     NF            0     0      1      0
# 1920        yemen  2012   6   6     NF            0     0      1      0
# 1921        yemen  2013   6   6     NF            0     0      1      0
# 1922        yemen  2014   6   6     NF            0     0      1      0
# 1923        yemen  2015   7   6     NF            0     0      1      0
# 1924        yemen  2016   7   6     NF            0     0      1      0
# 1925        yemen  2017   7   6     NF            0     0      1      0
# 1926       zambia  2008   3   3     PF            1     0      0      1
# 1927       zambia  2009   3   4     PF            1     0      0      1
# 1928       zambia  2010   3   4     PF            1     0      0      1
# 1929       zambia  2011   3   4     PF            1     0      0      1
# 1930       zambia  2012   3   4     PF            1     0      0      1
# 1931       zambia  2013   3   4     PF            1     0      0      1
# 1932       zambia  2014   3   4     PF            1     0      0      1
# 1933       zambia  2015   3   4     PF            1     0      0      1
# 1934       zambia  2016   4   4     PF            1     0      0      1
# 1935       zambia  2017   4   4     PF            1     0      0      1
# 1936     zimbabwe  2008   7   6     NF            0     0      1      0
# 1937     zimbabwe  2009   6   6     NF            0     0      1      0
# 1938     zimbabwe  2010   6   6     NF            0     0      1      0
# 1939     zimbabwe  2011   6   6     NF            0     0      1      0
# 1940     zimbabwe  2012   6   6     NF            0     0      1      0
# 1941     zimbabwe  2013   5   6     NF            0     0      1      0
# 1942     zimbabwe  2014   5   6     NF            0     0      1      0
# 1943     zimbabwe  2015   5   5     PF            1     0      0      1
# 1944     zimbabwe  2016   5   5     PF            1     0      0      1
# 1945     zimbabwe  2017   6   5     NF            0     0      1      0
#
#       BMR_democracy  ...  v2eldonate_ord  v2elpubfin_ord  v2elembaut_ord  \
# 0               0.0  ...             2.0             0.0             2.0
# 1               0.0  ...             2.0             0.0             2.0
# 2               0.0  ...             2.0             0.0             2.0
# 3               0.0  ...             2.0             0.0             2.0
# 4               0.0  ...             2.0             0.0             2.0
# 5               0.0  ...             2.0             0.0             1.0
# 6               0.0  ...             2.0             0.0             1.0
# 7               0.0  ...             2.0             0.0             1.0
# 8               NaN  ...             2.0             0.0             1.0
# 9               NaN  ...             2.0             0.0             1.0
# 10              1.0  ...             2.0             3.0             2.0
# 11              1.0  ...             2.0             3.0             2.0
# 12              1.0  ...             2.0             3.0             2.0
# 13              1.0  ...             2.0             3.0             2.0
# 14              1.0  ...             2.0             3.0             2.0
# 15              1.0  ...             2.0             2.0             2.0
# 16              1.0  ...             2.0             2.0             2.0
# 17              1.0  ...             2.0             2.0             2.0
# 18              NaN  ...             2.0             2.0             2.0
# 19              NaN  ...             2.0             2.0             3.0
# 20              0.0  ...             2.0             3.0             0.0
# 21              0.0  ...             2.0             3.0             0.0
# 22              0.0  ...             2.0             3.0             0.0
# 23              0.0  ...             2.0             3.0             0.0
# 24              0.0  ...             2.0             3.0             1.0
# 25              0.0  ...             2.0             3.0             0.0
# 26              0.0  ...             2.0             3.0             0.0
# 27              0.0  ...             2.0             3.0             0.0
# 28              NaN  ...             2.0             3.0             1.0
# 29              NaN  ...             2.0             3.0             0.0
# ...             ...  ...             ...             ...             ...
# 1916            0.0  ...             1.0             2.0             1.0
# 1917            0.0  ...             1.0             2.0             1.0
# 1918            0.0  ...             1.0             2.0             1.0
# 1919            0.0  ...             1.0             2.0             2.0
# 1920            0.0  ...             1.0             2.0             2.0
# 1921            0.0  ...             1.0             2.0             2.0
# 1922            0.0  ...             1.0             2.0             1.0
# 1923            0.0  ...             1.0             2.0             1.0
# 1924            NaN  ...             0.0             2.0             1.0
# 1925            NaN  ...             0.0             1.0             0.0
# 1926            1.0  ...             0.0             0.0             3.0
# 1927            1.0  ...             0.0             0.0             3.0
# 1928            1.0  ...             0.0             0.0             3.0
# 1929            1.0  ...             0.0             0.0             3.0
# 1930            1.0  ...             0.0             0.0             3.0
# 1931            1.0  ...             0.0             0.0             3.0
# 1932            1.0  ...             0.0             0.0             3.0
# 1933            1.0  ...             0.0             0.0             3.0
# 1934            NaN  ...             0.0             0.0             2.0
# 1935            NaN  ...             0.0             0.0             2.0
# 1936            0.0  ...             1.0             2.0             0.0
# 1937            0.0  ...             1.0             2.0             1.0
# 1938            0.0  ...             1.0             2.0             1.0
# 1939            0.0  ...             1.0             2.0             1.0
# 1940            0.0  ...             1.0             2.0             1.0
# 1941            0.0  ...             1.0             1.0             1.0
# 1942            0.0  ...             1.0             1.0             1.0
# 1943            0.0  ...             1.0             1.0             1.0
# 1944            NaN  ...             1.0             1.0             1.0
# 1945            NaN  ...             1.0             1.0             0.0
#
#       v2elmulpar_ord  v2elvotbuy_ord  v2elfrcamp_ord  v2elfrfair_ord  \
# 0                NaN             NaN             NaN             NaN
# 1                3.0             0.0             2.0             2.0
# 2                3.0             1.0             2.0             2.0
# 3                NaN             NaN             NaN             NaN
# 4                NaN             NaN             NaN             NaN
# 5                NaN             NaN             NaN             NaN
# 6                2.0             1.0             2.0             2.0
# 7                NaN             NaN             NaN             NaN
# 8                NaN             NaN             NaN             NaN
# 9                NaN             NaN             NaN             NaN
# 10               NaN             NaN             NaN             NaN
# 11               4.0             1.0             2.0             3.0
# 12               NaN             NaN             NaN             NaN
# 13               NaN             NaN             NaN             NaN
# 14               NaN             NaN             NaN             NaN
# 15               4.0             1.0             1.0             3.0
# 16               NaN             NaN             NaN             NaN
# 17               NaN             NaN             NaN             NaN
# 18               NaN             NaN             NaN             NaN
# 19               4.0             1.0             2.0             3.0
# 20               NaN             NaN             NaN             NaN
# 21               3.0             1.0             2.0             1.0
# 22               NaN             NaN             NaN             NaN
# 23               NaN             NaN             NaN             NaN
# 24               3.0             1.0             1.0             2.0
# 25               NaN             NaN             NaN             NaN
# 26               3.0             1.0             2.0             1.0
# 27               NaN             NaN             NaN             NaN
# 28               NaN             NaN             NaN             NaN
# 29               3.0             1.0             2.0             1.0
# ...              ...             ...             ...             ...
# 1916             NaN             NaN             NaN             NaN
# 1917             NaN             NaN             NaN             NaN
# 1918             NaN             NaN             NaN             NaN
# 1919             NaN             NaN             NaN             NaN
# 1920             2.0             2.0             1.0             2.0
# 1921             NaN             NaN             NaN             NaN
# 1922             NaN             NaN             NaN             NaN
# 1923             NaN             NaN             NaN             NaN
# 1924             NaN             NaN             NaN             NaN
# 1925             NaN             NaN             NaN             NaN
# 1926             4.0             1.0             1.0             3.0
# 1927             NaN             NaN             NaN             NaN
# 1928             NaN             NaN             NaN             NaN
# 1929             4.0             1.0             1.0             3.0
# 1930             NaN             NaN             NaN             NaN
# 1931             NaN             NaN             NaN             NaN
# 1932             NaN             NaN             NaN             NaN
# 1933             4.0             1.0             0.0             2.0
# 1934             4.0             1.0             0.0             1.0
# 1935             NaN             NaN             NaN             NaN
# 1936             4.0             1.0             0.0             0.0
# 1937             NaN             NaN             NaN             NaN
# 1938             NaN             NaN             NaN             NaN
# 1939             NaN             NaN             NaN             NaN
# 1940             NaN             NaN             NaN             NaN
# 1941             4.0             1.0             0.0             2.0
# 1942             NaN             NaN             NaN             NaN
# 1943             NaN             NaN             NaN             NaN
# 1944             NaN             NaN             NaN             NaN
# 1945             NaN             NaN             NaN             NaN
#
#       v2elaccept_ord  v2elasmoff_ord  v2elintim
# 0                NaN             NaN        NaN
# 1                3.0             2.0     -0.421
# 2                3.0             2.0     -0.376
# 3                NaN             NaN        NaN
# 4                NaN             NaN        NaN
# 5                NaN             NaN        NaN
# 6                2.0             2.0     -0.353
# 7                NaN             NaN        NaN
# 8                NaN             NaN        NaN
# 9                NaN             NaN        NaN
# 10               NaN             NaN        NaN
# 11               3.0             2.0      0.093
# 12               NaN             NaN        NaN
# 13               NaN             NaN        NaN
# 14               NaN             NaN        NaN
# 15               3.0             2.0     -0.236
# 16               NaN             NaN        NaN
# 17               NaN             NaN        NaN
# 18               NaN             NaN        NaN
# 19               3.0             2.0     -0.203
# 20               NaN             NaN        NaN
# 21               2.0             2.0     -0.298
# 22               NaN             NaN        NaN
# 23               NaN             NaN        NaN
# 24               2.0             2.0     -0.493
# 25               NaN             NaN        NaN
# 26               1.0             2.0     -0.746
# 27               NaN             NaN        NaN
# 28               NaN             NaN        NaN
# 29               2.0             2.0     -0.691
# ...              ...             ...        ...
# 1916             NaN             NaN        NaN
# 1917             NaN             NaN        NaN
# 1918             NaN             NaN        NaN
# 1919             NaN             NaN        NaN
# 1920             4.0             2.0      0.232
# 1921             NaN             NaN        NaN
# 1922             NaN             NaN        NaN
# 1923             NaN             NaN        NaN
# 1924             NaN             NaN        NaN
# 1925             NaN             NaN        NaN
# 1926             3.0             2.0     -0.420
# 1927             NaN             NaN        NaN
# 1928             NaN             NaN        NaN
# 1929             4.0             2.0      0.039
# 1930             NaN             NaN        NaN
# 1931             NaN             NaN        NaN
# 1932             NaN             NaN        NaN
# 1933             2.0             2.0     -0.842
# 1934             2.0             2.0     -1.462
# 1935             NaN             NaN        NaN
# 1936             0.0             2.0     -1.390
# 1937             NaN             NaN        NaN
# 1938             NaN             NaN        NaN
# 1939             NaN             NaN        NaN
# 1940             NaN             NaN        NaN
# 1941             1.0             2.0      0.120
# 1942             NaN             NaN        NaN
# 1943             NaN             NaN        NaN
# 1944             NaN             NaN        NaN
# 1945             NaN             NaN        NaN
#
# [1946 rows x 75 columns]

# %% [markdown]
# **Classify countries that are free, partly free, not free as 2, 1, 0 respectively**

# %%
final_data['FH_category'] = 0

# %%
final_data['FH_category'].loc[final_data['Status'] == 'F'] = 2
# Out:
# /Users/sanittawan/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
final_data['FH_category'].loc[final_data['Status'] == 'PF'] = 1

# %%
final_data[['country', 'year', 'Status', 'FH_category']][:10]
# Out:
#        country  year Status  FH_category
# 0  afghanistan  2008     NF            0
# 1  afghanistan  2009     NF            0
# 2  afghanistan  2010     NF            0
# 3  afghanistan  2011     NF            0
# 4  afghanistan  2012     NF            0
# 5  afghanistan  2013     NF            0
# 6  afghanistan  2014     NF            0
# 7  afghanistan  2015     NF            0
# 8  afghanistan  2016     NF            0
# 9  afghanistan  2017     NF            0

# %%
final_data['is_erosion'] = 1

# %%
final_data['is_erosion'] = final_data['is_erosion'].where(final_data['Status'] == 'PF', 0)

# %%
final_data[['country', 'year', 'Status', 'is_erosion']]
# Out:
#           country  year Status  is_erosion
# 0     afghanistan  2008     NF           0
# 1     afghanistan  2009     NF           0
# 2     afghanistan  2010     NF           0
# 3     afghanistan  2011     NF           0
# 4     afghanistan  2012     NF           0
# 5     afghanistan  2013     NF           0
# 6     afghanistan  2014     NF           0
# 7     afghanistan  2015     NF           0
# 8     afghanistan  2016     NF           0
# 9     afghanistan  2017     NF           0
# 10        albania  2008     PF           1
# 11        albania  2009     PF           1
# 12        albania  2010     PF           1
# 13        albania  2011     PF           1
# 14        albania  2012     PF           1
# 15        albania  2013     PF           1
# 16        albania  2014     PF           1
# 17        albania  2015     PF           1
# 18        albania  2016     PF           1
# 19        albania  2017     PF           1
# 20        algeria  2008     NF           0
# 21        algeria  2009     NF           0
# 22        algeria  2010     NF           0
# 23        algeria  2011     NF           0
# 24        algeria  2012     NF           0
# 25        algeria  2013     NF           0
# 26        algeria  2014     NF           0
# 27        algeria  2015     NF           0
# 28        algeria  2016     NF           0
# 29        algeria  2017     NF           0
# ...           ...   ...    ...         ...
# 1916        yemen  2008     PF           1
# 1917        yemen  2009     NF           0
# 1918        yemen  2010     NF           0
# 1919        yemen  2011     NF           0
# 1920        yemen  2012     NF           0
# 1921        yemen  2013     NF           0
# 1922        yemen  2014     NF           0
# 1923        yemen  2015     NF           0
# 1924        yemen  2016     NF           0
# 1925        yemen  2017     NF           0
# 1926       zambia  2008     PF           1
# 1927       zambia  2009     PF           1
# 1928       zambia  2010     PF           1
# 1929       zambia  2011     PF           1
# 1930       zambia  2012     PF           1
# 1931       zambia  2013     PF           1
# 1932       zambia  2014     PF           1
# 1933       zambia  2015     PF           1
# 1934       zambia  2016     PF           1
# 1935       zambia  2017     PF           1
# 1936     zimbabwe  2008     NF           0
# 1937     zimbabwe  2009     NF           0
# 1938     zimbabwe  2010     NF           0
# 1939     zimbabwe  2011     NF           0
# 1940     zimbabwe  2012     NF           0
# 1941     zimbabwe  2013     NF           0
# 1942     zimbabwe  2014     NF           0
# 1943     zimbabwe  2015     PF           1
# 1944     zimbabwe  2016     PF           1
# 1945     zimbabwe  2017     NF           0
#
# [1946 rows x 4 columns]

# %%
final_data.columns
# Out:
# Index(['country', 'year', 'PR', 'CL', 'Status', 'FH_category', 'FH_F', 'FH_NF',
#        'FH_PF', 'BMR_democracy', 'BMR_democracy_trans',
#        'BMR_democracy_breakdowns', 'BMR_democracy_duration', 'v2lgfunds_ord',
#        'v2lgamend', 'v2exhoshog', 'v2exaphogp', 'v2exaphos', 'v2ddlexci',
#        'v2ddlexrf', 'v2ddlexpl', 'v2lginello', 'v2lginelup',
#        'v2exl_legitlead_ord', 'v2pepwrgeo_ord', 'v2clgencl_ord',
#        'v2clpolcl_ord', 'v2peapssoc_ord', 'v2peapsgen_ord', 'v2peapsecon_ord',
#        'v2peapspol_ord', 'v2peapsgeo_ord', 'v2pepwrses_ord', 'v2pepwrsoc_ord',
#        'v2pepwrgen_ord', 'v2peedueq_ord', 'v2pehealth_ord', 'v2mecenefm_ord',
#        'v2mecenefi_ord', 'v2mecrit_ord', 'v2meslfcen_ord', 'v2mebias_ord',
#        'v2mecorrpt_ord', 'v2cseeorgs_ord', 'v2csreprss_ord', 'v2cltrnslw_ord',
#        'v2clrspct_ord', 'v2cldiscm_ord', 'v2cldiscw_ord', 'v2jureform_ord',
#        'v2jupoatck_ord', 'v2jupack_ord', 'v2juhcind_ord', 'v2juncind_ord',
#        'v2jureview_ord', 'v2lgotovst_ord', 'v2lgoppart_ord', 'v2exremhsp_ord',
#        'v2exremhog_ord', 'v2exrescon_ord', 'v2exbribe_ord', 'v2psbars_ord',
#        'v2psoppaut_ord', 'v2psplats_ord', 'v2pscohesv_ord', 'v2eldonate_ord',
#        'v2elpubfin_ord', 'v2elembaut_ord', 'v2elmulpar_ord', 'v2elvotbuy_ord',
#        'v2elfrcamp_ord', 'v2elfrfair_ord', 'v2elaccept_ord', 'v2elasmoff_ord',
#        'v2elintim', 'is_erosion'],
#       dtype='object')

# %%
final_data.shape
# Out:
# (1946, 76)

# %%
final_data.to_csv('./democracy.csv', index=False)
